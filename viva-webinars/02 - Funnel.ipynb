# %%
import pandas as pd

# %%
# !ls data
# Out:
# 20200707_Informedeinscripción.csv   20200714_Informedeinscripción.csv
# 20200707_Informedelavotación.csv    20200714_meeting_saved_chat.csv
# 20200707_meeting_saved_chat.txt     20200714_meeting_saved_chat.txt
# 20200707_participants.csv

# %%
inscripcion = pd.read_csv('data/20200707_Informedeinscripción.csv')
votacion = pd.read_csv('data/20200707_Informedelavotación.csv')
participantes = pd.read_csv('data/20200707_participants.csv')

# %%
inscripcion.shape, votacion.shape, participantes.shape
# Out:
# ((1833, 9), (255, 5), (3943, 8))

# %%
inscripcion.head()
# Out:
#   First Name           Last Name                       Email  \
# 0    MARISOL        APAZA CANAZA     marisol252016@gmail.com
# 1     Albina     Tarazona campos       altaca_10@hotmail.com
# 2      NORMA       HUANACO APAZA       ALIVE_MCS_22@yahoo.es
# 3    Antonio     Aranngo Ventura       alhemakna@hotmail.com
# 4     Lusbel  Gonzales Santillan  lusbelgonzales83@gmail.com
#
#      Registration Time Approval Status           last_name  \
# 0  2020-07-07 19:09:33        approved        APAZA CANAZA
# 1  2020-07-07 19:12:52        approved     Tarazona campos
# 2  2020-07-07 20:50:21        approved       HUANACO APAZA
# 3  2020-07-07 14:37:23        approved     Aranngo Ventura
# 4  2020-07-07 21:17:16        approved  Gonzales Santillan
#
#                             Nombre de Institución        Región  Unnamed: 8
# 0                                       SALESIANO         CUSCO         NaN
# 1                                    Ugel Marañon       Huanuco         NaN
# ...

# %%
votacion.head()
# Out:
#                                                                                                                                                                                                                          #  \
# 1 Sonia Doris Pillaca Uchupe Soniadoris04@gmail.com      Jul 07, 2020 20:14:11 ¿Qué se evalúa? Competencias y capacidades                        ¿Cuánto te gusto el orador principal? Mucho     El portafolio sirve para:
# 2 Abel Zea Bendezú           abelzb24_2006@hotmail.com   Jul 07, 2020 20:13:31 ¿Qué se evalúa? Competencias y capacidades                        ¿Cuánto te gusto el orador principal? Mucho     El portafolio sirve para:
# 3 yanette Portugal Pujaico   yanetportugal1@gmail.com    Jul 07, 2020 20:13:42 ¿Qué se evalúa? Competencias y capacidades                        ¿Cuánto te gusto el orador principal? Mucho     El portafolio sirve para:
# ...

# %%
participantes.head()
# Out:
#            ID de la reunión  \
# 0               89922766003
# 1  Nombre (nombre original)
# 2         Felicita Lizarazo
# 3    Aurelio FLORES CONDORI
# 4         Felicita Lizarazo
#
#                                                 Tema          Hora de inicio  \
# 0  Webinar VIVA: "Evaluación Formativa y el porta...  07/07/2020 05:55:41 PM
# 1                                 E-mail del usuario        Hora para unirse
# 2                             micheche17@hotmail.com  07/07/2020 06:58:22 PM
# 3                         aurelioflores122@gmail.com  07/07/2020 06:58:40 PM
# 4                             micheche17@hotmail.com  07/07/2020 07:01:04 PM
#
#      Hora de finalización      E-mail del usuario  Duración (minutos)  \
# 0  07/07/2020 08:17:08 PM  jmdelariva@viva.org.pe               142.0
# 1         Hora para salir      Duración (minutos)                 NaN
# 2  07/07/2020 07:00:54 PM                       3                 NaN
# ...
